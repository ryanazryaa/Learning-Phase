# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanazryaa/Learning-Phase/blob/main/4_30_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Learning from this youtube video :https://www.youtube.com/watch?v=_uQrJ0TkZlc&t=6116s

# %% [markdown]
# For Loops

# %%
for item in ['Mosh', 'John', 'Sarah']:
  print(item)
# Out:
# Mosh
# John
# Sarah

# %%
for item in range(5,10,2):
  print(item)
# Out:
# 5
# 7
# 9

# %%
#EXERCISE QUESTION
#PRICES
#FOR LOOP TO CALCULATE THE TOTAL PRICE

# %%
#My Solution
prices = [10, 20, 30]
total = 0
for item in prices:
  total += item
print(f"Total: {total}")
# Out:
# Total: 60

# %%
#Video's Solution
prices = [10, 20, 30]
total = 0
for item in prices:
  total += item
print(f"Total: {total}")

# %% [markdown]
# Nested Loops

# %%
#Nested Loops is a loop inside another loop

# %%
#Example: Coordinates
for x in range(4):
  for y in range(3):
    print(f'({x}, {y})')
# Out:
# (0, 0)
# (0, 1)
# (0, 2)
# (1, 0)
# (1, 1)
# (1, 2)
# (2, 0)
# (2, 1)
# (2, 2)
# (3, 0)
# (3, 1)
# (3, 2)

# %%
#EXERCISE QUESTION
#Given List of Numbers
#Make a Line containing Numbers of x
#Do it again until the very last number

# %%
#Video's Solution
numbers = [5, 2, 5, 2, 2]
for x in numbers:
  output = ''
  for y in range(x):
    output += 'x'
  print(output)

  #I didnt know how even when i was thinking for like 15 minutes so i just skipped and now i understand
# Out:
# xxxxx
# xx
# xxxxx
# xx
# xx

# %%
numbers = [2, 2, 2, 2, 5]
for x in numbers:
  output = ''
  for y in range(x):
    output += 'x'
  print(output)
# Out:
# xx
# xx
# xx
# xx
# xxxxx

# %% [markdown]
# Lists

# %%
names = ['John', 'Bob', 'Mosh', 'Sarah', 'Mary']
print(names[0])
# Out:
# John

# %%
names = ['John', 'Bob', 'Mosh', 'Sarah', 'Mary']
print(names[-1])
# Out:
# Mary

# %%
names = ['John', 'Bob', 'Mosh', 'Sarah', 'Mary']
print(names[2:])
# Out:
# ['Mosh', 'Sarah', 'Mary']

# %%
names = ['John', 'Bob', 'Mosh', 'Sarah', 'Mary']
print(names[2:4])
# Out:
# ['Mosh', 'Sarah']

# %%
names = ['John', 'Bob', 'Mosh', 'Sarah', 'Mary']
names[0] = 'Jon'
print(names)
# Out:
# ['Jon', 'Bob', 'Mosh', 'Sarah', 'Mary']

# %%
#EXERCISE QUESTION
#LARGEST NUMBER IN LIST

# %%
numbers = [3, 6, 2, 8, 4, 10]
i = 0
max_number = numbers[0]
for i in numbers:
  if i >= max_number:
    max_number = i
print(max_number)
# Out:
# 10

# %%
#At this point, i am urged to go learn on kaggle learn (urged by claude ai btw). So i think in colab this is it for today.

# %% [markdown]
# Im not gonna lie, kaggle learn gets from 0 to 100 fast. Im already confused at the second lesson. I dont understand how do i learn this at kaggle cause kaggle just throws you at the material head first and doesnt explain it simple.
