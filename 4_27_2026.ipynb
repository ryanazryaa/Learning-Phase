# %%
print("Hello World")
# Out:
# Hello World

# %%
age = 20
price = 19.95
first_name = 'Ryan'
is_online = False
print(age)
# Out:
# 30

# %%
name = "John Smith"
age = 20
is_new = True

# %%
name = input("What is your name? ")
print("Hello " + name)
# Out:
# What is your name? Ryan
# Hello Ryan

# %%
birth_year = input("Enter your birth year : ")
age = 2022 - int(birth_year)
print("You are " + str(age) + " years old.")
# Out:
# Enter your birth year : 1998
# You are 24 years old.

# %%
number1 = input('First : ')
number2 = input('Second : ')
Sum = float(number1) + float(number2)
print('Sum : ' + str(Sum))
# Out:
# First : 10
# Second : 20.1
# Sum : 30.1

# %%
course = 'Python for Beginners'
print('Python' in course)
# Out:
# False

# %%
course = 'Python for Beginners'
course.replace('Python','Go')
# Out:
# 'Go for Beginners'

# %%
print(10 ** 3)
print(10 / 3)
print(10 // 3)
print(10 % 3)
# Out:
# 1000
# 3.3333333333333335
# 3
# 1

# %%
x = 10
x = x + 3
x += 3

# %%
x = (10 + 3) * 2
print(x)
# Out:
# 26

# %%
x = 3 != 2
print(x)
# Out:
# True

# %%
price = 5
print(not price > 10)
# Out:
# True

# %%
temperature = 10

if temperature > 30:
  print("It's a hot day")
  print("Drink plenty of water")
elif temperature > 20: # (20, 30)
  print("It's a nice day")
elif temperature > 10:
  print("It's a bit cold")
else:
  print("It's cold")
print("Done")
# Out:
# It's cold
# Done

# %%
weight = float(input("Weight : "))
what_type = input("(K)g or (L)bs : ")
if what_type.upper() == "K":
  converted = float(weight) / 0.45
  print("Weight in Lbs : " + str(converted))
elif what_type.upper() == "L":
  converted = float(weight) * 0.45
  print("Weight in Kgs : " + str(converted))
# Out:
# Weight : 170
# (K)g or (L)bs : l
# Weight in Kgs : 76.5
