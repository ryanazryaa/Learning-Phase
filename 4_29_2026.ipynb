# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanazryaa/Learning-Phase/blob/main/4_29_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# While loops

# %%
i = 1
while i <= 5:
  print(i)
  i = i + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i <= 10:
  print(i * '*')
  i = i + 1
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %%
#EXERCISE QUESTION
#Guess number
#if you didnt guess it you can try again for 2 more times until it says you failed

# %%
#My Solution
secret_number = 9
guess_count = 0

while guess_count < 3:
  guess = int(input("Guess: "))
  if guess != secret_number:
    guess_count += 1
  elif guess == secret_number:
    print("You Win!")
    break
if guess_count == 3:
  print("Sorry You Failed!")
# Out:
# Guess: 9
# You Win!

# %%
#Video's Solution
secret_number = 9
guess_count = 0
guess_limit = 3

while guess_count < guess_limit:
  guess = int(input("Guess: "))
  guess_count += 1
  if guess == secret_number:
    print("You Win!")
    break
else:
  print("Sorry You Failed!")
# Out:
# Guess: 1
# Guess: 1
# Guess: 1
# Sorry You Failed!

# %% [markdown]
# Lists

# %%
names = ["John", "Bob", "Mosh", "Mary"]
print(names)
# Out:
# ['John', 'Bob', 'Mosh', 'Mary']

# %%
names = ["John", "Bob", "Mosh", "Mary"]
print(names[0])
# Out:
# John

# %%
names = ["John", "Bob", "Mosh", "Mary"]
print(names[-1])
# Out:
# Mary

# %%
names = ["John", "Bob", "Mosh", "Mary"]
print(names[0:3])
# Out:
# ['John', 'Bob', 'Mosh']

# %% [markdown]
# Lists Method

# %%
numbers = [1, 2, 3, 4, 5]
numbers.append(6)
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
numbers = [1, 2, 3, 4, 5]
numbers.insert(0, -1)
print(numbers)
# Out:
# [-1, 1, 2, 3, 4, 5]

# %%
numbers = [1, 2, 3, 4, 5]
numbers.remove(2)
print(numbers)
# Out:
# [1, 3, 4, 5]

# %%
numbers = [1, 2, 3, 4, 5]
numbers.clear()
print(numbers)
# Out:
# []

# %%
numbers = [1, 2, 3, 4, 5]
print(10 in numbers)
# Out:
# False

# %%
numbers = [1, 2, 3, 4, 5]
print(len(numbers))
# Out:
# 5

# %% [markdown]
# For Loops

# %%
numbers = [1, 2, 3, 4, 5]
for item in numbers:
  print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#same thing but while loop
numbers = [1, 2, 3, 4, 5]
i = 0
while i < len(numbers):
  print(numbers[i])
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# The range() function

# %%
numbers = range(5) # 0 to 4
print(numbers)
# Out:
# range(0, 5)

# %%
numbers = range(5) # 0 to 4
for number in numbers:
  print(number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
numbers = range(5, 10) # 5 to 9
for number in numbers:
  print(number)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
numbers = range(5, 10, 2) # jumps 2 numbers so 5, 7, 9
for number in numbers:
  print(number)
# Out:
# 5
# 7
# 9

# %%
for number in range(5) :
  print(number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Tuples

# %%
numbers = (1, 2, 3, 3)
numbers.count(3)
# Out:
# 2

# %%
numbers = (1, 2, 3, 3)
numbers.index(3)
# Out:
# 2

# %% [markdown]
# NEW VIDEO : now learning from https://www.youtube.com/watch?v=_uQrJ0TkZlc(Python Full Course for Beginners) by Programming with Mosh. But, im only learning the parts i havent learned before

# %% [markdown]
# Formatted Strings

# %%
first = 'John'
last = 'Smith'
message = first + ' [' + last + '] is a coder '
print(message)
# Out:
# John [Smith] is a coder

# %%
first = 'John'
last = 'Smith'
message = first + ' [' + last + '] is a coder '
msg = f'{first} {last} is a coder'
print(msg)
# Out:
# John Smith is a coder

# %% [markdown]
# If Statements

# %%
is_hot = True

if is_hot:
  print("It's a hot day")
print("Enjoy your day")
# Out:
# It's a hot day
# Enjoy your day

# %%
is_hot = True

if is_hot:
  print("It's a hot day")
  print("Drink plenty of water")
print("Enjoy your day")
# Out:
# It's a hot day
# Drink plenty of water
# Enjoy your day

# %%
is_hot = False

if is_hot:
  print("It's a hot day")
  print("Drink plenty of water")
else:
  print("It's a cold day")
  print("Wear warm clothes")
print("Enjoy your day")
# Out:
# It's a cold day
# Wear warm clothes
# Enjoy your day

# %%
is_hot = False
is_cold = True

if is_hot:
  print("It's a hot day")
  print("Drink plenty of water")
elif is_cold:
     print("It's a cold day")
     print("Wear warm clothes")
else:
  print("It's a lovely day")
print("Enjoy your day")
# Out:
# It's a cold day
# Wear warm clothes
# Enjoy your day

# %%
is_hot = False
is_cold = False

if is_hot:
  print("It's a hot day")
  print("Drink plenty of water")
elif is_cold:
     print("It's a cold day")
     print("Wear warm clothes")
else:
  print("It's a lovely day")
print("Enjoy your day")
# Out:
# It's a lovely day
# Enjoy your day

# %%
EXERCISE QUESTION
#price is 1M$
#good credit = 10% down payment
#else = 20% down payment
#print the down payment if the buyer has good credit

# %%
#My Solution
price = 1000000
good_credit = True

if good_credit:
  down_payment = int(price) * 1/10
  print("Down Payment: " + str(down_payment))
else:
  down_payment = int(price) * 2/10
  print("Down Payment: " + str(down_payment))
# Out:
# Down Payment: 100000.0

# %%
#Video's Solution
price = 1000000
has_good_credit = True

if has_good_credit:
  down_payment = 0.1 * price
else:
  down_payment = 0.2 * price
print(f'Down Payment: {down_payment}')
# Out:
# Down Payment: 100000.0

# %% [markdown]
# Logical Operators

# %%
has_high_income = True
has_good_credit = True

if has_good_credit and has_high_income:
  print("Eligible for loan")
# Out:
# Eligible for loan

# %%
has_high_income = False
has_good_credit = True

if has_good_credit and has_high_income:
  print("Eligible for loan")

# %%
has_high_income = False
has_good_credit = True

if has_good_credit or has_high_income:
  print("Eligible for loan")
# Out:
# Eligible for loan

# %%
has_high_income = False
has_good_credit = False

if has_good_credit or has_high_income:
  print("Eligible for loan")

# %%
has_criminal_record = True
has_good_credit = True

if has_good_credit or not has_criminal_record:
  print("Eligible for loan")
# Out:
# Eligible for loan

# %%
has_criminal_record = True
has_good_credit = False

if has_good_credit or not has_criminal_record:
  print("Eligible for loan")

# %% [markdown]
# Comparison Operators

# %%
# There are 5 comparison operators
# Greater than (>) Greater than or equal (>=) Lesser than (<) Lesser than or equal to (<=) Equal (==)
temperature = 35

if temperature > 30:
  print("It's a hot day")
else:
  print("It's not a hot day")
# Out:
# It's a hot day

# %%
temperature = 30

if temperature > 30:
  print("It's a hot day")
else:
  print("It's not a hot day")
# Out:
# It's not a hot day

# %%
#EXERCISE QUESTION
#if name is less than 3 characters long then name must be at least 3 characters
#otherwise if its more than 50 characters long then name can be maximum 50 characters
#otherwise name looks good

# %%
#My Solution
name = input("What is your name: ")

if len(name) < 3:
  print("Name must be at least 3 characters.")
elif len(name) > 50:
  print("Name can be maximum 50 characters.")
else:
  print("Name looks good!")
# Out:
# What is your name: Ryan
# Name looks good!

# %%
#Video's Solution
name =  "J"

if len(name) < 3:
  print("Name must be at least 3 characters.")
elif len(name) > 50:
  print("Name must be maximum 50 characters.")
else:
  print("Name looks good!")

# %%
#EXERCISE QUESTION
#Enter Weight
#Lbs or Kgs
#Output the weight in the other unit

# %%
#My Solution
weight = int(input("Weight: "))
unit = input("(L)bs or (K)gs: ")

if unit.upper() == "K":
  converted = weight / 0.45
  print(f'You are {converted} Lbs')
elif unit.upper() == "L":
  converted = weight * 0.45
  print(f'You are {converted} Kgs')
else:
  print("Invalid Input")
# Out:
# Weight: 170
# (L)bs or (K)gs: l
# You are 76.5 Kgs

# %%
#Video's Solution
weight = int(input('Weight: '))
unit = input('(L)bs or (K)g: ')
if unit.upper() == 'L':
  converted = weight * 0.45
  print(f'You are {converted} kilos')
elif unit.upper() == 'K':
  converted = weight / 0.45
  print(f'You are {converted} pounds')
# Out:
# Weight: 170
# (L)bs or (K)g: l
# You are 76.5 kilos

# %% [markdown]
# Car Game Exercise

# %%
#My Solution
text = input()
while text.upper() != "HELP":
  text = input()
else :
    if text.upper() == "HELP":
      print("Start - to start the car")
      print("Stop - to stop the car")
      print("Quit - to exit")

      text2 = input().upper()
      while text2 != "QUIT":
        if text2 == "START":
          print("Car Started...Ready to go!")
          text2 = input().upper()
        elif text2 == "STOP":
          print("Car stopped.")
          text2 = input().upper()
        else:
          print("I don't understand that...")
          text2 = input().upper()
    else:
      print("I dont understand that...")
      text = input().upper()

      #DIFFERENCES
      #WRONG CONDITION ON WHILE
      #DOESNT HAVE > ON INPUT
      #WRONG CONDITION ON ELSE
      #CANT QUIT AT START OF RUNNING
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_35317/4224354943.py in <cell line: 0>()
#       1 #My Solution
# ----> 2 text = input()
#       3 while text.upper() != "HELP":
#       4   text = input()
#       5 else :
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
#Video's Solution
command = ""
while True:
  command = input("> ").lower()
  if command == "start":
    print("Car started... Ready to go!")
  elif command == "stop":
    print("Car stopped.")
  elif command == "help":
    print("""
start - to start the car
stop - to stop the car
quit - to quit
    """)
  elif command == "quit":
    break
  else:
    print("Sorry, I don't understand that...")
# Out:
# > quit

# %% [markdown]
# EXTRA QUESTION

# %%
#My Solution
command = ""
started = False
stopped = False
while True:
  command = input("> ").lower()
  if command == "start":
    if started:
      print("Car has already started.")
    else:
      started = True
      stopped = False
      print("Car started... Ready to go!")

  elif command == "stop":
    if stopped:
      print("Car has already stopped.")
    else:
      stopped = True
      started = False
      print("Car stopped.")
  elif command == "help":
    print("""
start - to start the car
stop - to stop the car
quit - to quit
    """)
  elif command == "quit":
    break
  else:
    print("Sorry, I don't understand that...")

#i didnt know what to do so i took a peek to look for clues in the video and i eventually got it
# Out:
# > start
# Car started... Ready to go!
# > stop
# Car stopped.
# > start
# Car started... Ready to go!
# > start
# Car has already started.
# > stop
# Car stopped.
# > stop
# Car has already stopped.
# > quit
